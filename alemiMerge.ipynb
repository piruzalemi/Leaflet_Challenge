# %%
# import pandas as pd

# %%
import pandas as pd

# %%
history_price_df = pd.read_html('https://inkplant.com/code/state-latitudes-longitudes')[0]
history_price_df
# Out:
#                    State   Latitude   Longitude
# 0                Alabama  32.806671  -86.791130
# 1                 Alaska  61.370716 -152.404419
# 2                Arizona  33.729759 -111.431221
# 3               Arkansas  34.969704  -92.373123
# 4             California  36.116203 -119.681564
# 5               Colorado  39.059811 -105.311104
# 6            Connecticut  41.597782  -72.755371
# 7               Delaware  39.318523  -75.507141
# 8   District of Columbia  38.897438  -77.026817
# 9                Florida  27.766279  -81.686783
# 10               Georgia  33.040619  -83.643074
# 11                Hawaii  21.094318 -157.498337
# 12                 Idaho  44.240459 -114.478828
# 13              Illinois  40.349457  -88.986137
# 14               Indiana  39.849426  -86.258278
# 15                  Iowa  42.011539  -93.210526
# 16                Kansas  38.526600  -96.726486
# 17              Kentucky  37.668140  -84.670067
# 18             Louisiana  31.169546  -91.867805
# ...

# %%
history_price_df = pd.read_html('https://finance.yahoo.com/quote/SPY/history?p=SPY')[0]
history_price_df
# Out:
#                                                   Date  \
# 0                                         Mar 04, 2020
# 1                                         Mar 03, 2020
# 2                                         Mar 02, 2020
# 3                                         Feb 28, 2020
# 4                                         Feb 27, 2020
# ..                                                 ...
# 96                                        Oct 16, 2019
# 97                                        Oct 15, 2019
# 98                                        Oct 14, 2019
# 99                                        Oct 11, 2019
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                   Open  \
# 0                                               306.12
# 1                                               309.50
# 2                                               298.21
# 3                                               288.70
# ...

# %%
history_price_df =history_price_df.iloc[:3]
history_price_df
# Out:
#            Date    Open    High     Low  Close* Adj Close**     Volume
# 0  Mar 04, 2020  306.12  313.10  303.33  312.86      312.86  176025500
# 1  Mar 03, 2020  309.50  313.84  297.57  300.24      300.24  300139100
# 2  Mar 02, 2020  298.21  309.16  294.46  309.09      309.09  238703600

# %%
Options_df = pd.read_html('https://finance.yahoo.com/quote/SPY/options?p=SPY')[0]
Options_df.head()
# Out:
#         Contract Name         Last Trade Date  Strike  Last Price    Bid  \
# 0  SPY200306C00210000   2020-03-03 4:06PM EST   210.0       86.65   0.00
# 1  SPY200306C00215000   2020-03-03 3:51PM EST   215.0       81.66   0.00
# 2  SPY200306C00230000  2020-03-02 12:23PM EST   230.0       72.00   0.00
# 3  SPY200306C00233000  2020-03-03 10:06PM EST   233.0       66.86  72.64
# 4  SPY200306C00235000   2020-03-02 3:47PM EST   235.0       75.62   0.00
#
#      Ask  Change % Change Volume Open Interest Implied Volatility
# 0   0.00     0.0        -      -             0              0.00%
# 1   0.00     0.0        -      -             0              0.00%
# 2   0.00     0.0        -      -             0              0.00%
# 3  73.52     0.0        -      -             -              0.00%
# 4   0.00     0.0        -      -             0              0.00%

# %%
Options_df.dtypes
# Out:
# Contract Name          object
# Last Trade Date        object
# Strike                float64
# Last Price            float64
# Bid                    object
# Ask                   float64
# Change                float64
# % Change               object
# Volume                 object
# Open Interest          object
# Implied Volatility     object
# dtype: object

# %%
Options_df['Last Trade Date'] = Options_df['Last Trade Date'].map(lambda x:x.split(' ')[0])

# %%
Options_df = Options_df.rename(columns={"Last Trade Date": "Date"})
Options_df = Options_df.sort_values(by='Date', ascending=False)

Options_df['Date'] = pd.to_datetime(Options_df['Date'])
begin_date = '2020-01-27'
Options_df = Options_df.loc[(Options_df['Date'] >= begin_date)]
Options_df
# Out:
#           Contract Name       Date  Strike  Last Price   Bid  Ask  Change  \
# 77   SPY200306C00308000 2020-03-04   308.0        6.11  0.00  0.0     0.0
# 80   SPY200306C00309500 2020-03-04   309.5        5.00  0.00  0.0     0.0
# 93   SPY200306C00320000 2020-03-04   320.0        0.63  0.00  0.0     0.0
# 92   SPY200306C00319000 2020-03-04   319.0        0.82  0.00  0.0     0.0
# 91   SPY200306C00318000 2020-03-04   318.0        1.09  0.00  0.0     0.0
# ..                  ...        ...     ...         ...   ...  ...     ...
# 145  SPY200306C00363000 2020-02-19   363.0        0.01  0.00  0.0     0.0
# 148  SPY200306C00366000 2020-02-19   366.0        0.01  0.00  0.0     0.0
# 149  SPY200306C00367000 2020-02-18   367.0        0.01  0.00  0.0     0.0
# 144  SPY200306C00362500 2020-02-14   362.5        0.01  0.00  0.0     0.0
# 152  SPY200306C00370000 2020-02-12   370.0        0.01  0.00  0.0     0.0
#
#     % Change Volume Open Interest Implied Volatility
# ...

# %%
candidates_df = pd.read_csv('data_president_primary_polls.csv')
candidates_df
# Out:
# /Users/piruzalemi/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        question_id  poll_id  cycle state  pollster_id  \
# 0           119604    64702   2020   NaN         1189
# 1           119604    64702   2020   NaN         1189
# 2           119604    64702   2020   NaN         1189
# 3           119604    64702   2020   NaN         1189
# 4           119627    64708   2020   NaN          568
# ...            ...      ...    ...   ...          ...
# 18289        92392    57184   2020   NaN         1416
# 18290        92392    57184   2020   NaN         1416
# 18291        92392    57184   2020   NaN         1416
# 18292        92392    57184   2020   NaN         1416
# 18293        92392    57184   2020   NaN         1416
#
# ...

# %%
historical_price_df = pd.read_csv('SPY.csv')
historical_price_df = historical_price_df.sort_values(by='Date', ascending=False)
historical_price_df['Date'] = pd.to_datetime(historical_price_df['Date'])
most_one_week_df = historical_price_df.loc[(historical_price_df['Date'] >= begin_date)]
most_one_week_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-cb371e58e7d9> in <module>
# ----> 1 historical_price_df = pd.read_csv('SPY.csv')
#       2 historical_price_df = historical_price_df.sort_values(by='Date', ascending=False)
#       3 historical_price_df['Date'] = pd.to_datetime(historical_price_df['Date'])
#       4 most_one_week_df = historical_price_df.loc[(historical_price_df['Date'] >= begin_date)]
#       5 most_one_week_df
#
# ...

# %%
Stock_Option_df = pd.merge(Options_df, most_one_week_df, on='Date', how='left')

# %%
Stock_Option_df

# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import Session
import psycopg2 
import io

# %%
# Path to SQL_PGADMIN
#database_path = "http://localhost:5432/stockoptions"
# .   Connects!
#engine = create_engine('postgresql://postgres:yzp911107@localhost:5432/',pool_size=20,max_overflow=-1)
#connection = engine.connect()
#conn = engine.connect()

# %%
# Path to SQlAdmin
database_path = "http://localhost:5432/SPY"

# %%
# .  does connect
engine = create_engine('postgresql://postgres:Roshan2017@localhost:5432/SPY',pool_size=20,max_overflow=-1)
#connection = engine.connect()
conn = engine.connect()
# https://martin-thoma.com/configuration-files-in-python/

# %%
Stock_Option_sql = Stock_Option_df.rename(columns={"Contract Name":"ContractName",
                                               "Last Price":"LastPrice",
                                               "% Change":"PercentChange",
                                               "Open Interest":"OpenInterest",
                                               "Implied Volatility":"ImpliedVolatility",
                                               "Adj Close":"AdjClose",
                                                  "Open":"OpenPrice",
                                                  "Close":"ClosePrice"})

# %%
Stock_Option_sql.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-4054d005cd22> in <module>
# ----> 1 Stock_Option_sql.head()
#
# NameError: name 'Stock_Option_sql' is not defined

# %%
session = Session(bind=engine)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-3bb9c030c504> in <module>
# ----> 1 session = Session(bind=engine)
#
# NameError: name 'Session' is not defined

# %%
#session.add(Stock_Option_sql)

# %%
Stock_Option_sql.to_sql(name="contracts", con=engine, if_exists="replace", index=False)

# %%
# The above parameters can be "Replace", "Append" and "Fail"!
